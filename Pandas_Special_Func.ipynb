# %%
import pandas as pd
import numpy as np

# %%
subs = pd.read_csv("subs.csv").squeeze()

# %%
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
vk = pd.read_csv("kohli_ipl.csv",index_col="match_no").squeeze()

# %%
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movies = pd.read_csv("bollywood.csv",index_col="movie").squeeze()

# %%
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
vk.head()
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
#astype
import sys
sys.getsizeof(vk)
# Out:
# 3472

# %%
new_vk = vk.astype('int8')

# %%
sys.getsizeof(new_vk)
# Out:
# 1967

# %%
#between
vk[vk.between(51,99)].size
# Out:
# 43

# %%
#clip
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
subs.clip(100,200)
# Out:
# 0      100
# 1      100
# 2      100
# 3      100
# 4      100
#       ...
# 360    200
# 361    200
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
temp = pd.Series([1, 2, np.nan, 4, np.nan, 6, 7, np.nan, 9, np.nan])

# %%
temp.count
# Out:
# <bound method Series.count of 0    1.0
# 1    2.0
# 2    NaN
# 3    4.0
# 4    NaN
# 5    6.0
# 6    7.0
# 7    NaN
# 8    9.0
# 9    NaN
# dtype: float64>

# %%
temp.drop_duplicates()
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# 3    4.0
# 5    6.0
# 6    7.0
# 8    9.0
# dtype: float64

# %%
temp[temp.duplicated()]
# Out:
# 4   NaN
# 7   NaN
# 9   NaN
# dtype: float64

# %%
temp.isnull().sum()
# Out:
# 4

# %%
temp.dropna()
# Out:
# 0    1.0
# 1    2.0
# 3    4.0
# 5    6.0
# 6    7.0
# 8    9.0
# dtype: float64

# %%
temp.fillna(temp.mean())
# Out:
# 0    1.000000
# 1    2.000000
# 2    4.833333
# 3    4.000000
# 4    4.833333
# 5    6.000000
# 6    7.000000
# 7    4.833333
# 8    9.000000
# 9    4.833333
# dtype: float64

# %%
temp[temp.isin([2,3,4,6])]
# Out:
# 1    2.0
# 3    4.0
# 5    6.0
# dtype: float64

# %%
vk[vk.apply(lambda x : x == 50)]
# Out:
# match_no
# 15     50
# 182    50
# Name: runs, dtype: int64

# %%
vk.apply(lambda x : x)
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
subs.apply(lambda x : "good day" if x > subs.mean()else "bad day")
# Out:
# 0       bad day
# 1       bad day
# 2       bad day
# 3       bad day
# 4       bad day
#          ...
# 360    good day
# 361    good day
# 362    good day
# 363    good day
# 364    good day
# Name: Subscribers gained, Length: 365, dtype: object

# %%
movies.apply (lambda x : x.split()[0].upper())
# Out:
# movie
# Uri: The Surgical Strike                  VICKY
# Battalion 609                             VICKY
# The Accidental Prime Minister (film)     ANUPAM
# Why Cheat India                          EMRAAN
# Evening Shadows                            MONA
#                                          ...
# Hum Tumhare Hain Sanam                     SHAH
# Aankhen (2002 film)                     AMITABH
# Saathiya (film)                           VIVEK
# Company (film)                             AJAY
# Awara Paagal Deewana                     AKSHAY
# Name: lead, Length: 1500, dtype: object

# %%
vk.head()
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
new_vk = vk.head()

# %%
new_vk[1] = 100

# %%
new_vk
# Out:
# match_no
# 1    100
# 2     23
# 3     13
# 4     12
# 5      1
# Name: runs, dtype: int64

# %%
vk
# Out:
# match_no
# 1      100
# 2       23
# 3       13
# 4       12
# 5        1
#       ...
# 211      0
# 212     20
# 213     73
# 214     25
# 215      7
# Name: runs, Length: 215, dtype: int64

# %%
new_vk = vk.head().copy()

# %%
new_vk
# Out:
# match_no
# 1    100
# 2     23
# 3     13
# 4     12
# 5      1
# Name: runs, dtype: int64

# %%
new_vk[1] = 1

# %%
new_vk
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
vk
# Out:
# match_no
# 1      100
# 2       23
# 3       13
# 4       12
# 5        1
#       ...
# 211      0
# 212     20
# 213     73
# 214     25
# 215      7
# Name: runs, Length: 215, dtype: int64
