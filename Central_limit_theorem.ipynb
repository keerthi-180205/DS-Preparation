# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
n = 10
p = 0.5
size = 1000

binomial_dist = np.random.binomial(n, p ,size)

# %%
binomial_dist
plt.hist(binomial_dist)
# Out:
# (array([ 11.,  44., 125., 204., 238., 212., 122.,  34.,   8.,   2.]),
#  array([ 1. ,  1.9,  2.8,  3.7,  4.6,  5.5,  6.4,  7.3,  8.2,  9.1, 10. ]),
#  <BarContainer object of 10 artists>)

# %%
n = 10
p = 0.8
size = 1000

binomial_dist = np.random.binomial(n, p ,size)
binomial_dist
plt.hist(binomial_dist)
# Out:
# (array([  1.,  33.,   0.,  96.,   0., 212., 270.,   0., 288., 100.]),
#  array([ 4. ,  4.6,  5.2,  5.8,  6.4,  7. ,  7.6,  8.2,  8.8,  9.4, 10. ]),
#  <BarContainer object of 10 artists>)

# %%
n = 10
p = 0.2
size = 1000

binomial_dist = np.random.binomial(n, p ,size)
binomial_dist
plt.hist(binomial_dist)
# Out:
# (array([ 96., 281.,   0., 314.,   0., 201.,  74.,   0.,  22.,  12.]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <BarContainer object of 10 artists>)
