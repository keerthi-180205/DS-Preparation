# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Datasets/titanic.csv')

# %%
pop = df['Age'].dropna()

# %%
pop
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 714, dtype: float64

# %%
sample_age = pop.sample(25)

# %%
sample_age
# Out:
# 890    32.0
# 255    29.0
# 594    37.0
# 143    19.0
# 477    29.0
# 630    80.0
# 11     58.0
# 369    24.0
# 312    26.0
# 355    28.0
# 546    19.0
# 25     38.0
# 361    29.0
# 842    30.0
# 215    31.0
# 866    27.0
# 39     14.0
# 170    61.0
# 496    54.0
# 772    57.0
# 227    20.5
# 857    51.0
# 318    31.0
# 34     28.0
# 348     3.0
# Name: Age, dtype: float64

# %%
from scipy.stats import shapiro

# %%
shapiro_age = shapiro(sample)

# %%
shapiro_age # Normally distributed
# Out:
# ShapiroResult(statistic=0.9338481608810663, pvalue=0.10666660662014255)

# %%
pop_mean = 35

# %%
import scipy.stats as stats

# %%
t_stats , p_value = stats.ttest_1samp(sample_age,pop_mean)

# %%
print(t_stats)
print(p_value)
# Out:
# -0.22748421619715548
# 0.821973999627662

# %%
if p_value > 0.05 :
    print('not reject null hypothesis')
else:
    print('reject null hypothesis')
# Out:
# not reject null hypothesis

# %%
pop.mean()
# Out:
# 29.69911764705882
