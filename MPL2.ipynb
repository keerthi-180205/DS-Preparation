# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = pd.read_csv('Datasets/iris.csv')

# %%
iris.sample(5)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 41  42            4.5           2.3            1.3           0.3
# 97  98            6.2           2.9            4.3           1.3
# 32  33            5.2           4.1            1.5           0.1
# 24  25            4.8           3.4            1.9           0.2
# 74  75            6.4           2.9            4.3           1.3
#
#             Species
# 41      Iris-setosa
# 97  Iris-versicolor
# 32      Iris-setosa
# 24      Iris-setosa
# 74  Iris-versicolor

# %%
plt.figure(figsize = (10, 4))
iris['Species'] = iris['Species'].replace({'Iris-setosa' : 0, 'Iris-versicolor' : 1, 'Iris-virginica' : 2})
plt.scatter(iris['SepalLengthCm'], iris['PetalLengthCm'], c= iris['Species'], cmap =  'plasma',alpha = 0.5)
plt.title('Sepal Length vs Petal Length')
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.colorbar()
# Out:
# /tmp/ipykernel_8897/2289274643.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   iris['Species'] = iris['Species'].replace({'Iris-setosa' : 0, 'Iris-versicolor' : 1, 'Iris-virginica' : 2})

# %%
batsman = pd.read_csv('Datasets/batter.csv')

# %%
sample_df = batsman.head(100).sample(25, random_state = 42)

# %%
sample_df
# Out:
#            batter  runs        avg  strike_rate
# 83   MC Henriques  1000  27.777778   124.843945
# 53      MK Tiwary  1695  28.728814   113.834788
# 70       DJ Hooda  1237  20.278689   127.525773
# 45     AD Russell  2039  29.985294   168.234323
# 44   AC Gilchrist  2069  27.223684   133.054662
# 39     GJ Maxwell  2320  25.494505   147.676639
# 22       PA Patel  2848  22.603175   116.625717
# 80      SP Narine  1025  14.855072   154.367470
# 10      G Gambhir  4217  31.007353   119.665153
# 0         V Kohli  6634  36.251366   125.977972
# 18   F du Plessis  3403  34.373737   127.167414
# 30      RA Jadeja  2502  26.617021   122.108346
# 73     TM Dilshan  1153  26.813953   110.124164
# 33      DA Miller  2455  36.102941   133.569097
# 90         MM Ali   910  23.333333   139.570552
# 4        SK Raina  5536  32.374269   132.535312
# 76      ML Hayden  1107  35.709677   131.942789
# 77    LMP Simmons  1079  39.962963   122.892938
# 12      AM Rahane  4074  30.863636   117.575758
# 31      SPD Smith  2495  34.652778   124.812406
# 55  KC Sangakkara  1687  25.953846   118.469101
# 88      BA Stokes   920  25.555556   130.867710
# 26   Yuvraj Singh  2754  24.810811   124.784776
# 42  KS Williamson  2105  36.293103   123.315759
# 69     D Padikkal  1260  28.000000   119.205298

# %%
plt.figure(figsize = (15,9))
plt.scatter(sample_df['avg'], sample_df['strike_rate'],s = sample_df['runs'])

for i in range(sample_df.shape[0]):
    plt.text(sample_df['avg'].values[i], sample_df['strike_rate'].values[i], sample_df['batter'].values[i])

# %%
plt.figure(figsize = (15,9))
plt.scatter(sample_df['avg'], sample_df['strike_rate'],s = sample_df['runs'])
plt.axhline(130, color = 'red')
plt.axhline(140, color = 'green')
plt.axvline(28, color = 'red',)

for i in range(sample_df.shape[0]):
    plt.text(sample_df['avg'].values[i], sample_df['strike_rate'].values[i], sample_df['batter'].values[i])

# %%
plt.scatter(batsman['avg'], batsman['strike_rate'])

# %%
fig, ax = plt.subplots(figsize = (10,8))
ax.scatter(batsman['avg'], batsman['strike_rate'], color = 'red',cmap = 'plasma',alpha = 0.6)
ax.set_title('Avg vs Strike Rate')
ax.set_xlabel('Avg')
ax.set_ylabel('Strike Rate')
fig.show()
# Out:
# /tmp/ipykernel_8897/1873061003.py:2: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(batsman['avg'], batsman['strike_rate'], color = 'red',cmap = 'plasma',alpha = 0.6)
# /tmp/ipykernel_8897/1873061003.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(nrows = 2, ncols = 1, figsize=(10,10), sharex = True)
ax[0].scatter(batsman['avg'], batsman['strike_rate'],color = 'red', cmap = 'YIOrBr', alpha = 0.3)
ax[1].scatter(batsman['avg'], batsman['runs'],color = 'green', cmap = 'YIGnBu',alpha = 0.5)

ax[0].set_title('Avg vs Strike Rate')
ax[0].set_xlabel('Avg')
ax[0].set_ylabel('Strike Rate')

ax[1].set_title('Avg vs Runs')
ax[1].set_xlabel('Avg')
ax[1].set_ylabel('Runs')
# Out:
# /tmp/ipykernel_8897/3568026662.py:2: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax[0].scatter(batsman['avg'], batsman['strike_rate'],color = 'red', cmap = 'YIOrBr', alpha = 0.3)
# /tmp/ipykernel_8897/3568026662.py:3: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax[1].scatter(batsman['avg'], batsman['runs'],color = 'green', cmap = 'YIGnBu',alpha = 0.5)
# Text(0, 0.5, 'Runs')

# %%
fig, ax = plt.subplots(nrows = 2, ncols = 2, figsize=(10,6), sharex = True)
ax[0][0].scatter(batsman['avg'], batsman['strike_rate'],color = 'red', cmap = 'YIOrBr', alpha = 0.3)
ax[1][0].scatter(batsman['avg'], batsman['runs'],color = 'green', cmap = 'YIGnBu',alpha = 0.5)
ax[0][1].hist(batsman['avg'], bins = [10,20,30,40,50,60], color = 'orange',edgecolor='black', linewidth=1.5)
ax[1][1].hist(batsman['strike_rate'], bins = [80,100,120,140,160,180,200], color = 'cyan',edgecolor='black', linewidth=1.5)

ax[0][0].set_title('Avg vs Strike Rate')
ax[0][0].set_xlabel('Avg')
ax[0][0].set_ylabel('Strike Rate')

ax[1][0].set_title('Avg vs Runs')
ax[1][0].set_xlabel('Avg')
ax[1][0].set_ylabel('Runs')

ax[0][1].set_title('Avg runs by the blayers')
ax[0][1].set_xlabel('Avg')

ax[1][1].set_title('Strike Rate by the blayers')
ax[1][1].set_xlabel('Strike Rate')
fig.savefig('Sample Image')
# Out:
# /tmp/ipykernel_8897/419831935.py:2: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax[0][0].scatter(batsman['avg'], batsman['strike_rate'],color = 'red', cmap = 'YIOrBr', alpha = 0.3)
# /tmp/ipykernel_8897/419831935.py:3: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax[1][0].scatter(batsman['avg'], batsman['runs'],color = 'green', cmap = 'YIGnBu',alpha = 0.5)

# %% [markdown]
# 3D Scatter Plots

# %%
fig = plt.figure()
ax = plt.subplot(projection = '3d')
ax.scatter(batsman['runs'], batsman['avg'], batsman['strike_rate'])
ax.set_xlabel('Runs')
ax.set_ylabel('Avg')
ax.set_zlabel('SR')
# Out:
# Text(0.5, 0, 'SR')

# %%
x = [0,1,5,25]
y = [0,10,13,0]
z = [0,13,20,9]

fig = plt.figure()
ax = plt.subplot(projection = '3d')
ax.scatter(x,y,z,s=[100,100,100,100])
ax.plot(x,y,z)

# %% [markdown]
# 3D Surface Plots

# %%
x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)

xx, yy = np.meshgrid(x, y)

# %%
z = xx ** 3 + yy ** 3

# %%
fig = plt.figure(figsize = (10,6))
ax = plt.subplot(projection = '3d')

p = ax.plot_surface(xx, yy, z, cmap = 'viridis')
fig.colorbar(p)

# %%
z = xx ** 2 + yy ** 2
fig = plt.figure(figsize = (10,6))
ax = plt.subplot(projection = '3d')

p = ax.plot_surface(xx, yy, z, cmap = 'viridis')
fig.colorbar(p)

# %%
z = np.tan(xx) + np.cos(yy)
fig = plt.figure(figsize = (10,6))
ax = plt.subplot(projection = '3d')

p = ax.plot_surface(xx, yy, z, cmap = 'viridis')
fig.colorbar(p)

# %%
z = np.tan(xx) + np.cos(yy)
fig = plt.figure(figsize = (10,6))
ax = plt.subplot()

p = ax.contour(xx, yy, z, cmap = 'viridis')
fig.colorbar(p)

# %%
z = np.tan(xx) + np.cos(yy)
fig = plt.figure(figsize = (10,6))
ax = plt.subplot()

p = ax.contourf(xx, yy, z, cmap = 'viridis')
fig.colorbar(p)

# %%
z = np.sin(xx) + np.cos(yy)
fig = plt.figure(figsize = (10,6))
ax = plt.subplot()

p = ax.contour(xx, yy, z, cmap = 'viridis')
fig.colorbar(p)

# %%
z = np.sin(xx) + np.cos(yy)
fig = plt.figure(figsize = (10,6))
ax = plt.subplot()

p = ax.contourf(xx, yy, z, cmap = 'viridis')
fig.colorbar(p)

# %%
batsman = pd.read_csv("Datasets/IPL_Ball_by_Ball_2008_2022.csv")

# %%
batsman.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# 0                 0        NaN  NaN               NaN  Rajasthan Royals
# 1                 0        NaN  NaN               NaN  Rajasthan Royals
# 2                 0        NaN  NaN               NaN  Rajasthan Royals
# 3                 0        NaN  NaN               NaN  Rajasthan Royals
# 4                 0        NaN  NaN               NaN  Rajasthan Royals

# %%
temp_df = batsman[(batsman['ballnumber'].isin([1,2,3,4,5,6])) & (batsman['batsman_run'] == 6)]

# %%
grid =temp_df.pivot_table(index = 'overs', columns = 'ballnumber', values = 'batsman_run',aggfunc = 'count')

# %%
plt.figure(figsize = (20,10))
plt.imshow(grid)
plt.colorbar()

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
tips['size'] = tips['size'] * 50

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner   100
# 1       10.34  1.66    Male     No  Sun  Dinner   150
# 2       21.01  3.50    Male     No  Sun  Dinner   150
# 3       23.68  3.31    Male     No  Sun  Dinner   100
# 4       24.59  3.61  Female     No  Sun  Dinner   200

# %%
tips.plot(x = 'total_bill', y = 'tip', kind = 'scatter', alpha  = 0.5, s = 'size',c='sex', cmap = 'viridis')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
stocks = pd.read_csv('https://raw.githubusercontent.com/m-mehdi/pandas_tutorials/main/weekly_stocks.csv')
stocks.head()
# Out:
#          Date        MSFT          FB        AAPL
# 0  2021-05-24  249.679993  328.730011  124.610001
# 1  2021-05-31  250.789993  330.350006  125.889999
# 2  2021-06-07  257.890015  331.260010  127.349998
# 3  2021-06-14  259.429993  329.660004  130.460007
# 4  2021-06-21  265.019989  341.369995  133.110001

# %%
stocks['MSFT'].plot(kind = 'line')
# Out:
# <Axes: >

# %%
stocks.plot(kind = 'line', x = 'Date')
# Out:
# <Axes: xlabel='Date'>

# %%
tips.pivot_table(index=['day','time'],columns=['sex','smoker'],values='total_bill',aggfunc='mean').plot(kind='pie',subplots=True,figsize=(20,10))
# Out:
# /tmp/ipykernel_8897/2410627224.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   tips.pivot_table(index=['day','time'],columns=['sex','smoker'],values='total_bill',aggfunc='mean').plot(kind='pie',subplots=True,figsize=(20,10))
# array([<Axes: ylabel='(Male, Yes)'>, <Axes: ylabel='(Male, No)'>,
#        <Axes: ylabel='(Female, Yes)'>, <Axes: ylabel='(Female, No)'>],
#       dtype=object)
