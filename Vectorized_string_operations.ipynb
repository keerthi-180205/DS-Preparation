# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series(['cat', 'rat', None, 'mat'])

# %%
s
# Out:
# 0     cat
# 1     rat
# 2    None
# 3     mat
# dtype: object

# %%
s.str.startswith('s')
# Out:
# 0    False
# 1    False
# 2     None
# 3    False
# dtype: object

# %%
df = pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].str.lower()
# Out:
# 0                                braund, mr. owen harris
# 1      cumings, mrs. john bradley (florence briggs th...
# 2                                 heikkinen, miss. laina
# 3           futrelle, mrs. jacques heath (lily may peel)
# 4                               allen, mr. william henry
#                              ...
# 886                                montvila, rev. juozas
# 887                         graham, miss. margaret edith
# 888             johnston, miss. catherine helen "carrie"
# 889                                behr, mr. karl howell
# 890                                  dooley, mr. patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].str.upper()
# Out:
# 0                                BRAUND, MR. OWEN HARRIS
# 1      CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# 2                                 HEIKKINEN, MISS. LAINA
# 3           FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)
# 4                               ALLEN, MR. WILLIAM HENRY
#                              ...
# 886                                MONTVILA, REV. JUOZAS
# 887                         GRAHAM, MISS. MARGARET EDITH
# 888             JOHNSTON, MISS. CATHERINE HELEN "CARRIE"
# 889                                BEHR, MR. KARL HOWELL
# 890                                  DOOLEY, MR. PATRICK
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].str.capitalize()
# Out:
# 0                                Braund, mr. owen harris
# 1      Cumings, mrs. john bradley (florence briggs th...
# 2                                 Heikkinen, miss. laina
# 3           Futrelle, mrs. jacques heath (lily may peel)
# 4                               Allen, mr. william henry
#                              ...
# 886                                Montvila, rev. juozas
# 887                         Graham, miss. margaret edith
# 888             Johnston, miss. catherine helen "carrie"
# 889                                Behr, mr. karl howell
# 890                                  Dooley, mr. patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].str.title()
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'][df['Name'].str.len() == 82].values[0]
# Out:
# 'Penasco y Castellana, Mrs. Victor de Satode (Maria Josefa Perez de Soto y Vallejo)'

# %%
df['surname']  = df['Name'].str.split(',').str.get(0)

# %%
df[['title','firstname']] = df['Name'].str.split(',').str.get(1).str.strip().str.split(' ', n=1, expand=True)
df.head()

df['title'].value_counts()
# Out:
# title
# Mr.          517
# Miss.        182
# Mrs.         125
# Master.       40
# Dr.            7
# Rev.           6
# Mlle.          2
# Major.         2
# Col.           2
# the            1
# Capt.          1
# Ms.            1
# Sir.           1
# Lady.          1
# Mme.           1
# Don.           1
# Jonkheer.      1
# Name: count, dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['title'].value_counts()
# Out:
# title
# Mr.          517
# Miss.        182
# Mrs.         125
# Master.       40
# Dr.            7
# Rev.           6
# Mlle.          2
# Major.         2
# Col.           2
# the            1
# Capt.          1
# Ms.            1
# Sir.           1
# Lady.          1
# Mme.           1
# Don.           1
# Jonkheer.      1
# Name: count, dtype: int64

# %%
df['title'].value_counts()
# Out:
# title
# Mr.          517
# Miss.        182
# Mrs.         125
# Master.       40
# Dr.            7
# Rev.           6
# Mlle.          2
# Major.         2
# Col.           2
# the            1
# Capt.          1
# Ms.            1
# Sir.           1
# Lady.          1
# Mme.           1
# Don.           1
# Jonkheer.      1
# Name: count, dtype: int64

# %%
df[df['firstname'].str.startswith('A')]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 13            14         0       3         Andersson, Mr. Anders Johan
# 22            23         1       3         McGowan, Miss. Anna "Annie"
# 35            36         0       1      Holverson, Mr. Alexander Oskar
# 38            39         0       3  Vander Planke, Miss. Augusta Maria
# 61            62         1       1                 Icard, Miss. Amelie
# ..           ...       ...     ...                                 ...
# 842          843         1       1             Serepeca, Miss. Augusta
# 845          846         0       3                 Abbing, Mr. Anthony
# 866          867         1       2        Duran y More, Miss. Asuncion
# 875          876         1       3    Najib, Miss. Adele Kiamie "Jane"
# 876          877         0       3       Gustafsson, Mr. Alfred Ossian
#
#         Sex   Age  SibSp  Parch         Ticket     Fare Cabin Embarked  \
# ...

# %%
df[df['firstname'].str.endswith('A')]
# Out:
#      PassengerId  Survived  Pclass                   Name     Sex  Age  SibSp  \
# 64            65         0       1  Stewart, Mr. Albert A    male  NaN      0
# 303          304         1       2    Keane, Miss. Nora A  female  NaN      0
#
#      Parch    Ticket     Fare Cabin Embarked  surname  title firstname
# 64       0  PC 17605  27.7208   NaN        C  Stewart    Mr.  Albert A
# 303      0    226593  12.3500  E101        Q    Keane  Miss.    Nora A

# %%
# applying regex
# contains
# search john -> both case
df[df['firstname'].str.contains('john',case=False)]
# find lastnames with start and end char vowel
df[df['surname'].str.contains('^[^aeiouAEIOU].+[^aeiouAEIOU]$')]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 5              6         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 884          885         0       3
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#time stamp
pd.Timestamp('2026/6/6')
# Out:
# Timestamp('2026-06-06 00:00:00')

# %%
pd.Timestamp('2026-6-6')
# Out:
# Timestamp('2026-06-06 00:00:00')

# %%
pd.Timestamp('2026, 6, 6')
# Out:
# Timestamp('2026-06-06 00:00:00')

# %%
pd.Timestamp('6th June 2026')
# Out:
# Timestamp('2026-06-06 00:00:00')

# %%
pd.Timestamp('6th June 2026 10:56PM')
# Out:
# Timestamp('2026-06-06 22:56:00')

# %%
import datetime as dt

# %%
dt.datetime(2026,6,6,11,3)
# Out:
# datetime.datetime(2026, 6, 6, 11, 3)

# %%
x = pd.Timestamp(dt.datetime(2026,6,6,11,3,23))

# %%
x
# Out:
# Timestamp('2026-06-06 11:03:23')

# %%
x.year
# Out:
# 2026

# %%
x.month
# Out:
# 6

# %%
x.day
# Out:
# 6

# %%
x.hour
# Out:
# 11

# %%
x.minute
# Out:
# 3

# %%
x.second
# Out:
# 23

# %%
import numpy as np
date = np.array('2026-06-06', dtype=np.datetime64)
date
# Out:
# array('2026-06-06', dtype='datetime64[D]')

# %%
date + np.arange(12)
# Out:
# array(['2026-06-06', '2026-06-07', '2026-06-08', '2026-06-09',
#        '2026-06-10', '2026-06-11', '2026-06-12', '2026-06-13',
#        '2026-06-14', '2026-06-15', '2026-06-16', '2026-06-17'],
#       dtype='datetime64[D]')

# %%
pd.DatetimeIndex(['2026/6/6','2026/6/7','2026/6/8'])
# Out:
# DatetimeIndex(['2026-06-06', '2026-06-07', '2026-06-08'], dtype='datetime64[ns]', freq=None)

# %%
x = pd.DatetimeIndex([dt.datetime(2026, 6, 6, 11, 14, 23),dt.datetime(2026, 6, 7, 11, 14, 23),dt.datetime(2026, 6, 8, 11, 14, 23)])[0]

# %%
x.year
# Out:
# 2026

# %%
y = pd.DatetimeIndex([dt.datetime(2026, 6, 6, 11, 14, 23),dt.datetime(2026, 6, 7, 11, 14, 23),pd.Timestamp(2026, 6, 8, 11, 14, 23)])

# %%
y.day
# Out:
# Index([6, 7, 8], dtype='int32')

# %%
#daterange
pd.date_range(start = '2026-6-1', end = '2026-7-1', freq = 'D')
# Out:
# DatetimeIndex(['2026-06-01', '2026-06-02', '2026-06-03', '2026-06-04',
#                '2026-06-05', '2026-06-06', '2026-06-07', '2026-06-08',
#                '2026-06-09', '2026-06-10', '2026-06-11', '2026-06-12',
#                '2026-06-13', '2026-06-14', '2026-06-15', '2026-06-16',
#                '2026-06-17', '2026-06-18', '2026-06-19', '2026-06-20',
#                '2026-06-21', '2026-06-22', '2026-06-23', '2026-06-24',
#                '2026-06-25', '2026-06-26', '2026-06-27', '2026-06-28',
#                '2026-06-29', '2026-06-30', '2026-07-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start = '2026-6-1', end = '2026-7-1', freq = '2D')
# Out:
# DatetimeIndex(['2026-06-01', '2026-06-03', '2026-06-05', '2026-06-07',
#                '2026-06-09', '2026-06-11', '2026-06-13', '2026-06-15',
#                '2026-06-17', '2026-06-19', '2026-06-21', '2026-06-23',
#                '2026-06-25', '2026-06-27', '2026-06-29', '2026-07-01'],
#               dtype='datetime64[ns]', freq='2D')

# %%
pd.date_range(start = '2026-6-1', end = '2026-7-1', freq = '3D')
# Out:
# DatetimeIndex(['2026-06-01', '2026-06-04', '2026-06-07', '2026-06-10',
#                '2026-06-13', '2026-06-16', '2026-06-19', '2026-06-22',
#                '2026-06-25', '2026-06-28', '2026-07-01'],
#               dtype='datetime64[ns]', freq='3D')

# %%
pd.date_range(start = '2026-6-1', end = '2026-7-1', freq = 'B')
# Out:
# DatetimeIndex(['2026-06-01', '2026-06-02', '2026-06-03', '2026-06-04',
#                '2026-06-05', '2026-06-08', '2026-06-09', '2026-06-10',
#                '2026-06-11', '2026-06-12', '2026-06-15', '2026-06-16',
#                '2026-06-17', '2026-06-18', '2026-06-19', '2026-06-22',
#                '2026-06-23', '2026-06-24', '2026-06-25', '2026-06-26',
#                '2026-06-29', '2026-06-30', '2026-07-01'],
#               dtype='datetime64[ns]', freq='B')

# %%
pd.date_range(start = '2026-6-1', end = '2026-7-1', freq = 'W')
# Out:
# DatetimeIndex(['2026-06-07', '2026-06-14', '2026-06-21', '2026-06-28'], dtype='datetime64[ns]', freq='W-SUN')

# %%
pd.date_range(start = '2026-6-1', end = '2026-7-1', freq = 'H')
# Out:
# /tmp/ipykernel_10085/2365236986.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   pd.date_range(start = '2026-6-1', end = '2026-7-1', freq = 'H')
# DatetimeIndex(['2026-06-01 00:00:00', '2026-06-01 01:00:00',
#                '2026-06-01 02:00:00', '2026-06-01 03:00:00',
#                '2026-06-01 04:00:00', '2026-06-01 05:00:00',
#                '2026-06-01 06:00:00', '2026-06-01 07:00:00',
#                '2026-06-01 08:00:00', '2026-06-01 09:00:00',
#                ...
#                '2026-06-30 15:00:00', '2026-06-30 16:00:00',
#                '2026-06-30 17:00:00', '2026-06-30 18:00:00',
#                '2026-06-30 19:00:00', '2026-06-30 20:00:00',
#                '2026-06-30 21:00:00', '2026-06-30 22:00:00',
#                '2026-06-30 23:00:00', '2026-07-01 00:00:00'],
#               dtype='datetime64[ns]', length=721, freq='h')

# %%
pd.date_range(start = '2026-6-1', end = '2026-7-1', freq = '6H')
# Out:
# /tmp/ipykernel_10085/1954654756.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   pd.date_range(start = '2026-6-1', end = '2026-7-1', freq = '6H')
# DatetimeIndex(['2026-06-01 00:00:00', '2026-06-01 06:00:00',
#                '2026-06-01 12:00:00', '2026-06-01 18:00:00',
#                '2026-06-02 00:00:00', '2026-06-02 06:00:00',
#                '2026-06-02 12:00:00', '2026-06-02 18:00:00',
#                '2026-06-03 00:00:00', '2026-06-03 06:00:00',
#                ...
#                '2026-06-28 18:00:00', '2026-06-29 00:00:00',
#                '2026-06-29 06:00:00', '2026-06-29 12:00:00',
#                '2026-06-29 18:00:00', '2026-06-30 00:00:00',
#                '2026-06-30 06:00:00', '2026-06-30 12:00:00',
#                '2026-06-30 18:00:00', '2026-07-01 00:00:00'],
#               dtype='datetime64[ns]', length=121, freq='6h')

# %%
pd.date_range(start = '2026-6-1', end = '2030-7-1', freq = 'A')
# Out:
# /tmp/ipykernel_10085/658651649.py:1: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   pd.date_range(start = '2026-6-1', end = '2030-7-1', freq = 'A')
# DatetimeIndex(['2026-12-31', '2027-12-31', '2028-12-31', '2029-12-31'], dtype='datetime64[ns]', freq='YE-DEC')

# %%
pd.date_range(start='2023/1/5',periods=25,freq='M')
# Out:
# /tmp/ipykernel_10085/1551252460.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   pd.date_range(start='2023/1/5',periods=25,freq='M')
# DatetimeIndex(['2023-01-31', '2023-02-28', '2023-03-31', '2023-04-30',
#                '2023-05-31', '2023-06-30', '2023-07-31', '2023-08-31',
#                '2023-09-30', '2023-10-31', '2023-11-30', '2023-12-31',
#                '2024-01-31', '2024-02-29', '2024-03-31', '2024-04-30',
#                '2024-05-31', '2024-06-30', '2024-07-31', '2024-08-31',
#                '2024-09-30', '2024-10-31', '2024-11-30', '2024-12-31',
#                '2025-01-31'],
#               dtype='datetime64[ns]', freq='ME')

# %%
pd.date_range(start='2023/1/5',periods=25,freq='2D')
# Out:
# DatetimeIndex(['2023-01-05', '2023-01-07', '2023-01-09', '2023-01-11',
#                '2023-01-13', '2023-01-15', '2023-01-17', '2023-01-19',
#                '2023-01-21', '2023-01-23', '2023-01-25', '2023-01-27',
#                '2023-01-29', '2023-01-31', '2023-02-02', '2023-02-04',
#                '2023-02-06', '2023-02-08', '2023-02-10', '2023-02-12',
#                '2023-02-14', '2023-02-16', '2023-02-18', '2023-02-20',
#                '2023-02-22'],
#               dtype='datetime64[ns]', freq='2D')

# %%
s = pd.Series(['2026-6-6' , '2026-6-7', '2026-6-8'])

# %%
s
# Out:
# 0    2026-6-6
# 1    2026-6-7
# 2    2026-6-8
# dtype: object

# %%
pd.to_datetime(s).dt.day_name()
# Out:
# 0    Saturday
# 1      Sunday
# 2      Monday
# dtype: object

# %%
s = pd.Series(['2026-6-6' , '2026-63-7', '2026-6-8'])
pd.to_datetime(s, errors= 'coerce').dt.day_name()
# Out:
# 0    Saturday
# 1         NaN
# 2      Monday
# dtype: object

# %%
df = pd.read_csv('expense_data.csv')

# %%
df.head()
# Out:
#              Date               Account        Category  Subcategory  \
# 0  3/2/2022 10:11  CUB - online payment            Food          NaN
# 1  3/2/2022 10:11  CUB - online payment           Other          NaN
# 2  3/1/2022 19:50  CUB - online payment            Food          NaN
# 3  3/1/2022 18:56  CUB - online payment  Transportation          NaN
# 4  3/1/2022 18:22  CUB - online payment            Food          NaN
#
#                Note    INR Income/Expense  Note.1  Amount Currency  Account.1
# 0           Brownie   50.0        Expense     NaN    50.0      INR       50.0
# 1  To lended people  300.0        Expense     NaN   300.0      INR      300.0
# 2            Dinner   78.0        Expense     NaN    78.0      INR       78.0
# 3             Metro   30.0        Expense     NaN    30.0      INR       30.0
# 4            Snacks   67.0        Expense     NaN    67.0      INR       67.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            277 non-null    object
#  1   Account         277 non-null    object
#  2   Category        277 non-null    object
#  3   Subcategory     0 non-null      float64
#  4   Note            273 non-null    object
#  5   INR             277 non-null    float64
#  6   Income/Expense  277 non-null    object
#  7   Note.1          0 non-null      float64
#  8   Amount          277 non-null    float64
#  9   Currency        277 non-null    object
#  10  Account.1       277 non-null    float64
# dtypes: float64(5), object(6)
# memory usage: 23.9+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            277 non-null    datetime64[ns]
#  1   Account         277 non-null    object
#  2   Category        277 non-null    object
#  3   Subcategory     0 non-null      float64
#  4   Note            273 non-null    object
#  5   INR             277 non-null    float64
#  6   Income/Expense  277 non-null    object
#  7   Note.1          0 non-null      float64
#  8   Amount          277 non-null    float64
#  9   Currency        277 non-null    object
#  10  Account.1       277 non-null    float64
# dtypes: datetime64[ns](1), float64(5), object(5)
# memory usage: 23.9+ KB

# %%
df['Day'] = df['Date'].dt.day_name()

# %%
import matplotlib.pyplot as plt

# %%
df.groupby('Day')['INR'].mean().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Day'>

# %%
df['month'] = df['Date'].dt.month_name()

# %%
df.groupby('month')['INR'].sum().plot(kind = 'bar')
# Out:
# <Axes: xlabel='month'>

# %%
df[df['Date'].dt.is_month_end]
# Out:
#                    Date               Account        Category  Subcategory  \
# 7   2022-02-28 11:56:00  CUB - online payment            Food          NaN
# 8   2022-02-28 11:45:00  CUB - online payment           Other          NaN
# 61  2022-01-31 08:44:00  CUB - online payment  Transportation          NaN
# 62  2022-01-31 08:27:00  CUB - online payment           Other          NaN
# 63  2022-01-31 08:26:00  CUB - online payment  Transportation          NaN
# 242 2021-11-30 14:24:00  CUB - online payment            Gift          NaN
# 243 2021-11-30 14:17:00  CUB - online payment            Food          NaN
# 244 2021-11-30 10:11:00  CUB - online payment            Food          NaN
#
#                    Note     INR Income/Expense  Note.1  Amount Currency  \
# 7                 Pizza  339.15        Expense     NaN  339.15      INR
# 8           From kumara  200.00         Income     NaN  200.00      INR
# 61           Vnr to apk   50.00        Expense     NaN   50.00      INR
# ...
